# %%
import pandas as pd

# %%
raw_data = pd.read_csv("../data/processed/json_data_processed.csv")
data = raw_data.copy()
df = pd.DataFrame(data)
df.head()
# Out:
#        videoID           publishedAt                 channelId  \
# 0  uGtc9Bu9Txk  2020-12-31T23:00:10Z  UCArk93C2pbOvkv6jWz-3kAg
# 1  vAGmV-mRRT0  2020-12-24T07:00:08Z  UCArk93C2pbOvkv6jWz-3kAg
# 2  m54LPZSlStQ  2020-12-22T17:00:20Z  UCArk93C2pbOvkv6jWz-3kAg
# 3  1RcFj1Sfs58  2020-12-21T17:00:03Z  UCArk93C2pbOvkv6jWz-3kAg
# 4  MaJhyEr6csQ  2020-12-17T17:25:28Z  UCArk93C2pbOvkv6jWz-3kAg
#
#                                                title  \
# 0       🍾 FORD KIERNAN HOGMANAY SPECIAL! | Open Goal
# 1  CHRISTMAS EVE SPECIAL | Right in the Coupon w/...
# 2  EPIC CUP FINAL REVIEW | Keeping the Ball on th...
# 3               JAMIE CARRAGHER | Open Goal Meets...
# 4  CELTIC v HEARTS & ST MIRREN END RANGERS UNBEAT...
#
#                                          description channelTitle  \
# 0  SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 1  SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 2  SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 3  SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 4  SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
#
#                                                 tags  viewCount  likeCount  \
# 0  ['open goal', 'si ferry', 'still game', 'jack ...     205682       2286
# 1  ['open goal', 'si ferry', 'betting', 'slaney',...      63357        742
# 2  ['open goal', 'si ferry', 'celtic vs hearts', ...      85262        976
# 3  ['open goal', 'si ferry', 'Jamie Carragher', '...     855101       4966
# 4  ['open goal', 'si ferry', 'celtic v hearts', '...      64383        659
#
#    favoriteCount  commentCount duration_timedelta duration_hhmmss
# 0              0           112    0 days 01:21:55        01:21:55
# 1              0            30    0 days 00:44:31        00:44:31
# 2              0            63    0 days 01:06:12        01:06:12
# 3              0           661    0 days 02:22:14        02:22:14
# 4              0            49    0 days 00:45:40        00:45:40

# %% [markdown]
# # Top 10 videos for views, comments and likes

# %%
# define function for creating dataframes that sorts specific metrics
def single_metric_dataframes(df, metrics=[]):
    """Creates individual sorted dataframes for the given metrics. These dataframes can 
    then be used for analysis and visualisation.
    
    
    Parameters
    -----------
    df : pandas dataframe
        Dataframe that, ideally, contains the column names provided in the metrics list.
        
    metrics : list
        A list of column names.
        
        
    Returns
    ---------
    df : pandas dataframe(s)
        Returns a dataframe for each metric provided (assuming the metric is a column in
        the dataframe). The dataframe will be sorted from highest to lowest for the given
        metric.
        
    Notes
    ------
    Single metric error:
        Added logic that checked the length of the list generated during the execution of the function.
        This was because when there was only a single metric provided, a list was being returned insead of 
        the dataframe contained in the list. Explicitly transforming the single item to a dataframe with line
        
        df_sorted = pd.DataFrame(df_list[0])
        
        and  then returning the dataframe resolved this error.
    
    """
    
    metrics = list(metrics)
    
    df_list = []
    
    
    for i, v in enumerate(metrics):
        
        v = str(v)
        
        try: 
            df_ = (df[['videoID', 'title', 'publishedAt', v]]
                .sort_values(by=[v], ascending=False, axis=0)
                .reset_index(drop=True))

            df_list.append(df_)
            
        except KeyError as ke:
            
            print(f"""
            {ke} 
            Check that each column exists in the dataframe provided for the 'df' parameter. 
            Check the spelling of the column names provided for the 'metrics' parameter.
            Make sure the number of variables you are storing dataframes in matches the number of dataframe outputs. 
            """)
            
            pass
        
    
    # check length of dataframe list - this ensures that if only one metric is provided in the metrics parameter
    # then the dataframe is returned without error (was encountering an error when there was just a single item
    # in the list)
    if len(df_list) == 1:
        df_sorted = pd.DataFrame(df_list[0])
        return df_sorted
    
    
    elif len(df_list) > 1:
        
        return [df for df in df_list]

# %%
metrics_to_sort = ['viewCount', 'likeCount', 'commentCount']

df_test_views, df_test_likes, df_test_comments = single_metric_dataframes(df=df, metrics=metrics_to_sort)

# %%
df_test_views.head()
# Out:
#        videoID                                              title  \
# 0  s4LNJTRb2fM  Carragher On Getting Elbowed Off Big Duncan Fe...
# 1  1RcFj1Sfs58               JAMIE CARRAGHER | Open Goal Meets...
# 2  QJftaIBp_7o                     Si Ferry Meets... Ally McCoist
# 3  PPGdMhLZD_E           BEST TOMMY GRAVESEN STORIES! | Open Goal
# 4  l1elSsjrAUo  Si Ferry Meets... Andy Halliday | Life at Rang...
#
#             publishedAt  viewCount
# 0  2023-02-10T11:32:21Z     977573
# 1  2020-12-21T17:00:03Z     855101
# 2  2018-04-16T16:00:13Z     752340
# 3  2020-03-30T16:00:33Z     644369
# 4  2020-06-22T15:58:06Z     608241

# %%
df_test_likes.head()
# Out:
#        videoID                                              title  \
# 0  6KJM4qxvpUE  🤣 Hilarious Samuel Eto'o Story At Everton Told...
# 1  s4LNJTRb2fM  Carragher On Getting Elbowed Off Big Duncan Fe...
# 2  PJ-bTBsyYP4  🤢 "I WAS SICK EVERYWHERE!" | Andy Robertson On...
# 3  i_Ibl92_FoA    KIERAN TIERNEY | Keeping the Ball on the Ground
# 4  NblbQR4LuWA  "GERRARD WAS BETTER THAN LAMPARD & SCHOLES" | ...
#
#             publishedAt  likeCount
# 0  2023-02-17T15:16:47Z      16566
# 1  2023-02-10T11:32:21Z      15252
# 2  2023-03-13T19:20:50Z      11046
# 3  2020-08-19T16:00:33Z       7157
# 4  2023-04-19T10:52:17Z       7099

# %%
df_test_comments.head()
# Out:
#        videoID                                              title  \
# 0  NblbQR4LuWA  "GERRARD WAS BETTER THAN LAMPARD & SCHOLES" | ...
# 1  1RcFj1Sfs58               JAMIE CARRAGHER | Open Goal Meets...
# 2  HEA6ImXkPRQ  CELTIC NEAR TITLE AFTER BEATING RANGERS & HEAR...
# 3  _f1pase3Yp4  OPEN GOAL MEETS... ANGE POSTECOGLOU! | Glen's ...
# 4  VThQ2s6cXzA  CELTIC MANAGER ANGE POSTECOGLOU | Open Goal Me...
#
#             publishedAt  commentCount
# 0  2023-04-19T10:52:17Z          1218
# 1  2020-12-21T17:00:03Z           661
# 2  2023-04-11T16:00:11Z           529
# 3  2022-08-29T16:00:31Z           456
# 4  2023-06-01T16:00:19Z           424

# %%
metrics_t = ["viewCount"]
views = single_metric_dataframes(df=df, metrics=metrics_t)
views.head()
# Out:
#        videoID                                              title  \
# 0  s4LNJTRb2fM  Carragher On Getting Elbowed Off Big Duncan Fe...
# 1  1RcFj1Sfs58               JAMIE CARRAGHER | Open Goal Meets...
# 2  QJftaIBp_7o                     Si Ferry Meets... Ally McCoist
# 3  PPGdMhLZD_E           BEST TOMMY GRAVESEN STORIES! | Open Goal
# 4  l1elSsjrAUo  Si Ferry Meets... Andy Halliday | Life at Rang...
#
#             publishedAt  viewCount
# 0  2023-02-10T11:32:21Z     977573
# 1  2020-12-21T17:00:03Z     855101
# 2  2018-04-16T16:00:13Z     752340
# 3  2020-03-30T16:00:33Z     644369
# 4  2020-06-22T15:58:06Z     608241

# %%
metrics_t
# Out:
# ['viewCount']

# %% [markdown]
# # Split into KTBG, Si Ferry meets, Open Goal meets, Right in the coupon dataframes

# %%
df.loc[df['title'].str.contains("keeping", case=False)]
# Out:
#          videoID           publishedAt                 channelId  \
# 2    m54LPZSlStQ  2020-12-22T17:00:20Z  UCArk93C2pbOvkv6jWz-3kAg
# 5    BA057QKYWVo  2020-12-15T17:00:10Z  UCArk93C2pbOvkv6jWz-3kAg
# 8    ZJJ2KbWiWmM  2020-12-08T17:00:09Z  UCArk93C2pbOvkv6jWz-3kAg
# 11   YbI7c5Tgamw  2020-12-01T17:00:09Z  UCArk93C2pbOvkv6jWz-3kAg
# 13   LFNE2Vt_EAc  2020-11-25T17:00:06Z  UCArk93C2pbOvkv6jWz-3kAg
# ..           ...                   ...                       ...
# 718  vhq5cf4SbxQ  2022-08-23T16:11:06Z  UCArk93C2pbOvkv6jWz-3kAg
# 721  mBM0PcNb3dc  2022-08-16T17:34:51Z  UCArk93C2pbOvkv6jWz-3kAg
# 724  DdlDJWkYa44  2022-08-09T16:00:16Z  UCArk93C2pbOvkv6jWz-3kAg
# 728  uBmb8Tmaiq0  2022-08-02T16:00:29Z  UCArk93C2pbOvkv6jWz-3kAg
# 731  UETgeQ-AFJk  2022-07-26T16:00:13Z  UCArk93C2pbOvkv6jWz-3kAg
#
#                                                  title  \
# 2    EPIC CUP FINAL REVIEW | Keeping the Ball on th...
# 5    SCOTTISH CUP FINAL PREVIEW | Keeping the Ball ...
# 8    SLANEY HOSTS THE SHOW! | Keeping the Ball on t...
# 11   WHAT NEXT FOR CELTIC? | Keeping the Ball on th...
# 13   RANGERS EXTEND LEAD OVER CELTIC | Keeping the ...
# ..                                                 ...
# 718  CELTIC 2 POINTS CLEAR AT TOP AFTER 9-MAN RANGE...
# 721  WHO ON THE SHOW DOESN'T THINK JOTA'S THE BEST ...
# 724  MESSY FOOTBALLER NIGHTS OUT & DRAMATIC LATE SC...
# 728  RANGERS FACE CHAMPIONS LEAGUE TEST & MOTHERWEL...
# 731  2022/23 SPFL SCOTTISH PREMIERSHIP PREVIEW! | K...
#
#                                            description channelTitle  \
# 2    SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 5    SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 8    SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 11   SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 13   SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# ..                                                 ...          ...
# 718  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
# 721  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
# 724  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
# 728  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
# 731  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
#
#                                                   tags  viewCount  likeCount  \
# 2    ['open goal', 'si ferry', 'celtic vs hearts', ...      85262        976
# 5    ['open goal', 'si ferry', 'lewis capaldi', 'An...      90366        997
# 8    ['open goal', 'si ferry', 'Laura anderson', 'l...     124751       1548
# 11   ['open goal', 'si ferry', 'neil lennon', 'celt...     126504       1531
# 13   ['open goal', 'si ferry', 'slaney', 'Paul slan...     113102       1367
# ..                                                 ...        ...        ...
# 718  ['open goal', 'si ferry', 'simon ferry', 'celt...      58627        635
# 721  ['open goal', 'si ferry', 'simon ferry', 'rang...      68073        650
# 724  ['open goal', 'si ferry', 'simon ferry', 'Aide...      56964        628
# 728  ['open goal', 'si ferry', 'Simon ferry', 'Andy...      51380        535
# 731  ['open goal', 'si ferry', 'simon ferry', 'slan...      81769        949
#
#      favoriteCount  commentCount duration_timedelta duration_hhmmss
# 2                0            63    0 days 01:06:12        01:06:12
# 5                0            75    0 days 01:00:49        01:00:49
# 8                0           130    0 days 01:11:14        01:11:14
# 11               0           163    0 days 01:07:21        01:07:21
# 13               0            83    0 days 01:09:50        01:09:50
# ..             ...           ...                ...             ...
# 718              0           219    0 days 01:22:06        01:22:06
# 721              0           271    0 days 01:20:24        01:20:24
# 724              0           108    0 days 01:26:52        01:26:52
# 728              0           119    0 days 01:06:26        01:06:26
# 731              0           107    0 days 01:27:13        01:27:13
#
# [172 rows x 13 columns]

# %%
df.loc[df['title'].str.contains("keeping | messy", case=False)]
# Out:
#          videoID           publishedAt                 channelId  \
# 2    m54LPZSlStQ  2020-12-22T17:00:20Z  UCArk93C2pbOvkv6jWz-3kAg
# 5    BA057QKYWVo  2020-12-15T17:00:10Z  UCArk93C2pbOvkv6jWz-3kAg
# 8    ZJJ2KbWiWmM  2020-12-08T17:00:09Z  UCArk93C2pbOvkv6jWz-3kAg
# 11   YbI7c5Tgamw  2020-12-01T17:00:09Z  UCArk93C2pbOvkv6jWz-3kAg
# 13   LFNE2Vt_EAc  2020-11-25T17:00:06Z  UCArk93C2pbOvkv6jWz-3kAg
# ..           ...                   ...                       ...
# 718  vhq5cf4SbxQ  2022-08-23T16:11:06Z  UCArk93C2pbOvkv6jWz-3kAg
# 721  mBM0PcNb3dc  2022-08-16T17:34:51Z  UCArk93C2pbOvkv6jWz-3kAg
# 724  DdlDJWkYa44  2022-08-09T16:00:16Z  UCArk93C2pbOvkv6jWz-3kAg
# 728  uBmb8Tmaiq0  2022-08-02T16:00:29Z  UCArk93C2pbOvkv6jWz-3kAg
# 731  UETgeQ-AFJk  2022-07-26T16:00:13Z  UCArk93C2pbOvkv6jWz-3kAg
#
#                                                  title  \
# 2    EPIC CUP FINAL REVIEW | Keeping the Ball on th...
# 5    SCOTTISH CUP FINAL PREVIEW | Keeping the Ball ...
# 8    SLANEY HOSTS THE SHOW! | Keeping the Ball on t...
# 11   WHAT NEXT FOR CELTIC? | Keeping the Ball on th...
# 13   RANGERS EXTEND LEAD OVER CELTIC | Keeping the ...
# ..                                                 ...
# 718  CELTIC 2 POINTS CLEAR AT TOP AFTER 9-MAN RANGE...
# 721  WHO ON THE SHOW DOESN'T THINK JOTA'S THE BEST ...
# 724  MESSY FOOTBALLER NIGHTS OUT & DRAMATIC LATE SC...
# 728  RANGERS FACE CHAMPIONS LEAGUE TEST & MOTHERWEL...
# 731  2022/23 SPFL SCOTTISH PREMIERSHIP PREVIEW! | K...
#
#                                            description channelTitle  \
# 2    SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 5    SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 8    SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 11   SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 13   SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# ..                                                 ...          ...
# 718  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
# 721  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
# 724  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
# 728  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
# 731  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
#
#                                                   tags  viewCount  likeCount  \
# 2    ['open goal', 'si ferry', 'celtic vs hearts', ...      85262        976
# 5    ['open goal', 'si ferry', 'lewis capaldi', 'An...      90366        997
# 8    ['open goal', 'si ferry', 'Laura anderson', 'l...     124751       1548
# 11   ['open goal', 'si ferry', 'neil lennon', 'celt...     126504       1531
# 13   ['open goal', 'si ferry', 'slaney', 'Paul slan...     113102       1367
# ..                                                 ...        ...        ...
# 718  ['open goal', 'si ferry', 'simon ferry', 'celt...      58627        635
# 721  ['open goal', 'si ferry', 'simon ferry', 'rang...      68073        650
# 724  ['open goal', 'si ferry', 'simon ferry', 'Aide...      56964        628
# 728  ['open goal', 'si ferry', 'Simon ferry', 'Andy...      51380        535
# 731  ['open goal', 'si ferry', 'simon ferry', 'slan...      81769        949
#
#      favoriteCount  commentCount duration_timedelta duration_hhmmss
# 2                0            63    0 days 01:06:12        01:06:12
# 5                0            75    0 days 01:00:49        01:00:49
# 8                0           130    0 days 01:11:14        01:11:14
# 11               0           163    0 days 01:07:21        01:07:21
# 13               0            83    0 days 01:09:50        01:09:50
# ..             ...           ...                ...             ...
# 718              0           219    0 days 01:22:06        01:22:06
# 721              0           271    0 days 01:20:24        01:20:24
# 724              0           108    0 days 01:26:52        01:26:52
# 728              0           119    0 days 01:06:26        01:06:26
# 731              0           107    0 days 01:27:13        01:27:13
#
# [172 rows x 13 columns]

# %%
df.iloc[65]['title'] # index 65
# Out:
# 'Tubes from Soccer AM | Keeping the Ball on the Ground'

# %%
hearts = df.loc[(df['title'].str.contains("hearts", case=False)) |
      (df['title'].str.contains("scenes", case=False))]

hearts.reset_index(inplace=True, drop=True)

hearts.head()
# Out:
#        videoID           publishedAt                 channelId  \
# 0  MaJhyEr6csQ  2020-12-17T17:25:28Z  UCArk93C2pbOvkv6jWz-3kAg
# 1  xgkHjgCM6e4  2020-12-14T17:00:32Z  UCArk93C2pbOvkv6jWz-3kAg
# 2  LyJRTjESUAk  2020-10-07T16:00:04Z  UCArk93C2pbOvkv6jWz-3kAg
# 3  xW7I1EAVARc  2020-07-01T16:00:22Z  UCArk93C2pbOvkv6jWz-3kAg
# 4  65f09uZADrc  2020-03-05T17:00:00Z  UCArk93C2pbOvkv6jWz-3kAg
#
#                                                title  \
# 0  CELTIC v HEARTS & ST MIRREN END RANGERS UNBEAT...
# 1  Si Ferry Meets... Jon Daly | Cup Winner w/ Dun...
# 2  HALLIDAY SIGNS FOR HEARTS! | Keeping the Ball ...
# 3  Keeping the Ball on the Ground | w/ Andy Halli...
# 4  Right in the Coupon | Accies Shock Rangers, Li...
#
#                                          description channelTitle  \
# 0  SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 1  SUBSCRIBE to Open Goal - https://bit.ly/2QGY26...    Open Goal
# 2  SUBSCRIBE - https://bit.ly/2QGY26R\n\nThe gang...    Open Goal
# 3  SUBSCRIBE - https://bit.ly/2QGY26R\n\nAfter hi...    Open Goal
# 4  SUBSCRIBE - https://bit.ly/2QGY26R\n\nThe SPFL...    Open Goal
#
#                                                 tags  viewCount  likeCount  \
# 0  ['open goal', 'si ferry', 'celtic v hearts', '...      64383        659
# 1  ['open goal', 'si ferry', 'rangers', 'Steven g...      53065        437
# 2  ['open goal', 'si ferry', 'Paul Slane', 'Slane...     124173       1440
# 3  ['open goal', 'si ferry', 'si ferry meets Andy...      58497        710
# 4  ['open goal', 'si ferry', 'rangers accies', 'r...      35415        321
#
#    favoriteCount  commentCount duration_timedelta duration_hhmmss
# 0              0            49    0 days 00:45:40        00:45:40
# 1              0            43    0 days 01:41:23        01:41:23
# 2              0            80    0 days 01:12:48        01:12:48
# 3              0            62    0 days 01:00:47        01:00:47
# 4              0            29    0 days 00:33:05        00:33:05

# %%
hearts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   videoID             48 non-null     object
#  1   publishedAt         48 non-null     object
#  2   channelId           48 non-null     object
#  3   title               48 non-null     object
#  4   description         48 non-null     object
#  5   channelTitle        48 non-null     object
#  6   tags                48 non-null     object
#  7   viewCount           48 non-null     int64
#  8   likeCount           48 non-null     int64
#  9   favoriteCount       48 non-null     int64
#  10  commentCount        48 non-null     int64
#  11  duration_timedelta  48 non-null     object
#  12  duration_hhmmss     48 non-null     object
# dtypes: int64(4), object(9)
# memory usage: 5.0+ KB

# %%
for v in hearts["title"]:
    print(v)
    print("--------------------")
# Out:
# CELTIC v HEARTS & ST MIRREN END RANGERS UNBEATEN RUN | Right in the Coupon w/ Who Knows Wins
# --------------------
# Si Ferry Meets... Jon Daly | Cup Winner w/ Dundee Utd, Signing for Rangers, Hearts Interim Role
# --------------------
# HALLIDAY SIGNS FOR HEARTS! | Keeping the Ball on the Ground
# --------------------
# Keeping the Ball on the Ground | w/ Andy Halliday, Neilson to Hearts, Celtic GKs, Rangers Signings
# --------------------
# Right in the Coupon | Accies Shock Rangers, Livi for Europe? Hearts Win the Edinburgh Derby
# --------------------
# Si Ferry Meets... Jim Jefferies | Making History at Hearts, Romanov Era, Falkirk, Killie & Bradford
# --------------------
# KEEPING THE BALL ON THE GROUND | Gregg Wylde, Big Celtic Win, Hearts Calamity, Refs Giving Out Stick
# --------------------
# KEEPING THE BALL ON THE GROUND | Hearts Beat Rangers, Cummings Scores v Liverpool, Di Canio v Crouch
# --------------------
# Keeping the Ball on the Ground |Selling out the Hydro, Celtic v Rangers Review, More Drama at Hearts
# --------------------
# IT'S THE FINAL FIXTURES OF THE SEASON! DUNDEE UTD ON THE BRINK & HEARTS v HIBS | Right In The Coupon
# --------------------
# CELTIC BLITZ KILLIE, HIBS BEAT HEARTS & TOP 6 TO BE DECIDED! | Keeping The Ball On The Ground
# --------------------
# ROSS WILSON LEAVES RANGERS & IS SNODGRASS EXITING HEARTS AHEAD OF DERBY? | Right In The Coupon
# --------------------
# CELTIC NEAR TITLE AFTER BEATING RANGERS & HEARTS SACK NEILSON! | Keeping The Ball On The Ground
# --------------------
# KELTY HEARTS' MICHAEL TIDSER & TAM O'WARE GUEST ON THE SHOW! | Open Goal FC Podcast
# --------------------
# RANGERS BLOW HEARTS AWAY + SPFL TRANSFER WINDOW REVIEW | Right In The Coupon
# --------------------
# EPISODE 5 | EPIC SCENES ON AWAY DAY TRIP UP NORTH FOR BUCKIE TIE IN SCOTTISH CUP! Crossing The Line
# --------------------
# KYOGO SCORES LATE VS RANGERS & HEARTS BEAT HIBS IN DERBY | Keeping The Ball On The Ground
# --------------------
# RIGHT IN THE COUPON | Scotland Play-Offs, Rangers Chairman Steps Down, Hibs Flying & Hearts to Drop?
# --------------------
# RIGHT IN THE COUPON | Hearts & Levein, League Cup Semi Previews
# --------------------
# Si Ferry Meets... Craig Beattie | Martin O’Neill, Celtic Days, Hearts Cup Hero, Swansea, Travels
# --------------------
# RIGHT IN THE COUPON | Celtic UCL Exit, Barker at Ibrox, Poor starts for Hibs, Dons & Hearts
# --------------------
# Si Ferry Meets... Stevie Fulton | Celtic Breakthrough, Hearts, Scottish Cup Captain, Kilmarnock
# --------------------
# Si Ferry Meets... Ian Black | Blackburn & Souness, ICTFC, Hearts Days, Scottish Cup and Rangers
# --------------------
# Si Ferry Meets... Gary Naysmith | Hearts Days, Scottish Cup 98, Everton Years, Scotland
# --------------------
# RIGHT IN THE COUPON | Hearts v Celtic William Hill Scottish Cup Final Special
# --------------------
# RIGHT IN THE COUPON | Player of the Year Noms, Hibs v Hearts, Relegation & Title Deciding Weekend?
# --------------------
# RIGHT IN THE COUPON | Aberdeen on Sunday, Hearts in Final,  Will Celtic Win the Title this Weekend?
# --------------------
# RIGHT IN THE COUPON | Scottish Cup Special - Hearts v ICT & Aberdeen v Celtic
# --------------------
# Si Ferry Meets... Gary Locke | Living the Dream @ Hearts, 98 Cup Final, 2012 Cup Win, Gaffer & Admin
# --------------------
# RIGHT IN THE COUPON | Dons beat Rangers, Hearts off to Hampden, Celtic at Dens and The Drop
# --------------------
# Si Ferry Meets... David Templeton | Hearts Days, Anfield Goal, Rangers Move, McCoist & Injury Hell
# --------------------
# Si Ferry Meets... Paul Hartley | Romanov Era, Hearts Scottish Cup Win, Celtic 3IAR, Champions League
# --------------------
# RIGHT IN THE COUPON | Killie Beat Rangers, Celtic Signings & Dons Flying, Hearts & Hibs Defeats
# --------------------
# Si Ferry Meets... Ryan McGowan | Hearts , Scottish Cup, Managers, Rangers Offer, Dundee Utd & Oz
# --------------------
# Si Ferry Meets... Kevin Kyle - Sunderland Days, Scotland, Killie, Hearts and Rangers
# --------------------
# Si Ferry Meets... Davie Weir - Falkirk, Hearts, Everton, Playing and Coaching at Rangers
# --------------------
# RANGERS KNOCK-OUT CELTIC & HALLIDAY'S HEARTS ARE HEADING TO FINAL! Keeping The Ball On The Ground
# --------------------
# CELTIC VS RANGERS & HIBS VS HEARTS SCOTTISH CUP SEMI-FINAL PREVIEW | Right In The Coupon
# --------------------
# The Road To The Hydro: The Behind-The-Scenes Open Goal Documentary
# --------------------
# HEARTS SNATCH DRAMATIC DRAW AT IBROX & SKY HAVE NO SPFL GAMES ON TV🤯| Keeping The Ball On The Ground
# --------------------
# RANGERS BEAT CELTIC WITH HIBS & HEARTS TOP OF THE TABLE! | Keeping The Ball On The Ground
# --------------------
# HALLIDAY'S HEARTS BEAT CELTIC ON OPENING WEEKEND | Keeping The Ball On The Ground
# --------------------
# ROBBIE NEILSON | Open Goal Meets... Hearts Gaffer & Glen's Vodka SPFL Championship MOTM
# --------------------
# BRORA RANGERS BEAT HEARTS & CHE ADAMS TO START FOR SCOTLAND? | Right in the Coupon w/ Who Knows Wins
# --------------------
# ANDY HALLIDAY SCORES 2 WINNING GOALS IN A WEEK FOR HEARTS! | Keeping The Ball On The Ground
# --------------------
# EPISODE 2 | BEHIND-THE-SCENES OF ROLLERCOASTER 1ST FIVE GAMES | Crossing The Line Documentary
# --------------------
# SLANEY, BROADFOOT, BROQUE WATSON & KEV REACT TO BEHIND THE SCENES DOCUMENTARY | Open Goal FC Podcast
# --------------------
# MESSY FOOTBALLER NIGHTS OUT & DRAMATIC LATE SCENES IN EDINBURGH | Keeping The Ball On The Ground
# --------------------

# %%
# define function that takes in a dataframe and the name of a video series and returns the dataframe with all
# metrics for that video series only

def split_into_video_series(df, video_series_title=[]):
    """Takes in a dataframe and the name of a YouTube video series and returns the input dataframe with only
    the videos whose titles include the 'video_series_title' string in their title.
    
    Parameters
    ----------
    df : pandas dataframe
        Dataframe with YouTube video data.
        
    video_series_title : list
        List of strings of the title, or part of the title, of the video series we want to return a dataframe for.
        
    Returns
    -------
    df_ : dataframe
        Dataframe with only the rows whose video titles contain the specified 'video_series_title'.
        
    
    Notes
    ------
    
    
    """
    
    # check if input is a single string, if it is then store it as a single item list
    if isinstance(video_series_title, str):
        video_series_title = [video_series_title]
        
    # if input is a list then transform to lower case 
    elif isinstance(video_series_title, list):
        video_series_title = [x.lower() for x in video_series_title]
    
    
    # create empty list that will store dataframes which will be concatenated later
    df_list = []
    
    # check length of video_series_title list; if greater than 1 create multiple dataframes and then concatenate
    if len(video_series_title) > 1: 
        # loop through strings of video_series_title list
        for i, v in enumerate(video_series_title):
            
            # create dataframe with only the video titles that contain the specified string and append to list
            df_ = df.loc[df['title'].str.contains(v, case=False)] 
            df_list.append(df_)
            
        # concatenate dataframes, perform sorting and cleaning operations
        df_combined = pd.concat(df_list, ignore_index=True)
        df_combined = (df_combined
                       .sort_values(by=['publishedAt'])
                       .drop_duplicates()
                       .reset_index(drop=True))
        
        # return the dataframe
        return df_combined
        
            
    # check length of video_series_title list; if equal to 1 then use only item in list to create the dataframe
    elif len(video_series_title) == 1: 
        # create dataframe with only the video titles that contain the specified string and append to list
        df_ = df.loc[df['title'].str.contains(video_series_title[0], case=False)]
        # perform sorting and cleaning operations
        df_ = (df_
               .sort_values(by=['publishedAt'])
               .drop_duplicates()
               .reset_index(drop=True))
           
        # return dataframe
        return df_
    
    else: # no video series names/titles provided
        print("No changes made.")
        
        return df

# %%
ktbg = ["Keeping the Ball on the ground"]

df_ktbg = split_into_video_series(df=df, video_series_title=ktbg)
df_ktbg.head()
# Out:
# ['keeping the ball on the ground']
#        videoID           publishedAt                 channelId  \
# 0  rBT_-MHly6k  2019-02-19T16:57:04Z  UCArk93C2pbOvkv6jWz-3kAg
# 1  4SRWgzVRFTQ  2019-04-23T15:58:09Z  UCArk93C2pbOvkv6jWz-3kAg
# 2  4WeoL3HdIRI  2019-07-16T15:59:55Z  UCArk93C2pbOvkv6jWz-3kAg
# 3  Fx_pdL13V2I  2019-11-12T17:00:00Z  UCArk93C2pbOvkv6jWz-3kAg
# 4  x-GJDCp8R4Y  2019-11-19T17:00:18Z  UCArk93C2pbOvkv6jWz-3kAg
#
#                                                title  \
# 0  Keeping the Ball on the Ground | Charlie Mulgr...
# 1  Keeping the Ball on the Ground | Si Ferry, Ste...
# 2  Keeping the Ball on the Ground | Michael Gardy...
# 3  Keeping the Ball on the Ground | Celtic & Rang...
# 4  Keeping the Ball on the Ground | The Bee Inspi...
#
#                                          description channelTitle  \
# 0  SUBSCRIBE - https://bit.ly/2QGY26R\n\nWilliam ...    Open Goal
# 1  SUBSCRIBE - https://bit.ly/2QGY26R\n\nWilliam ...    Open Goal
# 2  SUBSCRIBE - https://bit.ly/2QGY26R\n\nWilliam ...    Open Goal
# 3  SUBSCRIBE - https://bit.ly/2QGY26R\n\nWilliam ...    Open Goal
# 4  SUBSCRIBE - https://bit.ly/2QGY26R\n\nWilliam ...    Open Goal
#
#                                                 tags  viewCount  likeCount  \
# 0  ['open goal', 'si ferry', 'celtic', 'celtic fc...     279470       2118
# 1  ['open goal', 'si ferry', 'rangers', 'river ci...      83380        601
# 2  ['open goal', 'si ferry', 'paul slane', 'tenan...      73130        379
# 3  ['open goal', 'si ferry', 'Paul Slane', 'celti...      67216        688
# 4  ['open goal', 'si ferry', 'Paul slane', 'Kevin...      55292        428
#
#    favoriteCount  commentCount duration_timedelta duration_hhmmss
# 0              0            98    0 days 00:48:25        00:48:25
# 1              0            31    0 days 00:54:35        00:54:35
# 2              0            29    0 days 01:06:50        01:06:50
# 3              0            41    0 days 00:56:47        00:56:47
# 4              0            16    0 days 00:56:18        00:56:18

# %%
# check if any titles DO NOT CONTAIN 'keeping the ball on the ground'
df_ktbg.loc[df_ktbg['title'].str.contains("keeping", case=False) == False]

# could also use ~ to achieve the same output as above
# df_ktbg.loc[~df_ktbg['title'].str.contains("Keeping the ball on the ground", case=False)]
# Out:
# Empty DataFrame
# Columns: [videoID, publishedAt, channelId, title, description, channelTitle, tags, viewCount, likeCount, favoriteCount, commentCount, duration_timedelta, duration_hhmmss]
# Index: []

# %%
scenes = "scenes"
df_scenes = split_into_video_series(df=df, video_series_title=scenes)
df_scenes.head()
# Out:
# ['scenes']
#        videoID           publishedAt                 channelId  \
# 0  KJDfF9XTuNs  2021-12-10T18:00:14Z  UCArk93C2pbOvkv6jWz-3kAg
# 1  DdlDJWkYa44  2022-08-09T16:00:16Z  UCArk93C2pbOvkv6jWz-3kAg
# 2  6Ae7RlJ9kbE  2022-09-07T15:00:03Z  UCArk93C2pbOvkv6jWz-3kAg
# 3  DQLSN_vj_eo  2022-10-09T07:00:03Z  UCArk93C2pbOvkv6jWz-3kAg
# 4  wqUWV8YGkvY  2023-01-29T08:00:32Z  UCArk93C2pbOvkv6jWz-3kAg
#
#                                                title  \
# 0  The Road To The Hydro: The Behind-The-Scenes O...
# 1  MESSY FOOTBALLER NIGHTS OUT & DRAMATIC LATE SC...
# 2  SLANEY, BROADFOOT, BROQUE WATSON & KEV REACT T...
# 3  EPISODE 2 | BEHIND-THE-SCENES OF ROLLERCOASTER...
# 4  EPISODE 5 | EPIC SCENES ON AWAY DAY TRIP UP NO...
#
#                                          description channelTitle  \
# 0  SUBSCRIBE - https://bit.ly/2QGY26R\n\nGo Behin...    Open Goal
# 1  ✅ SUBSCRIBE TO OPEN GOAL YOUTUBE CHANNEL FOR F...    Open Goal
# 2  🎫⚽️  Open Goal Broomhill FC vs Brora Rangers |...    Open Goal
# 3  👕 BUY THE OPEN GOAL BROOMHILL HOME & AWAY STRI...    Open Goal
# 4  🎟⚽️ OPEN GOAL BROOMHILL FC vs RANGERS FC B! GE...    Open Goal
#
#                                                 tags  viewCount  likeCount  \
# 0  ['open goal', 'si ferry', 'simon ferry', 'undr...     288043       3583
# 1  ['open goal', 'si ferry', 'simon ferry', 'Aide...      56964        628
# 2  ['open goal', 'si ferry', 'simon ferry', 'cros...      36295        402
# 3  ['open goal', 'si ferry', 'hashtag united', 'S...     107217       1334
# 4  ['open goal', 'si ferry', 'simon ferry', 'celt...      90468        836
#
#    favoriteCount  commentCount duration_timedelta duration_hhmmss
# 0              0           271    0 days 01:24:10        01:24:10
# 1              0           108    0 days 01:26:52        01:26:52
# 2              0            63    0 days 00:45:29        00:45:29
# 3              0           155    0 days 01:10:46        01:10:46
# 4              0           155    0 days 00:52:11        00:52:11

# %% [markdown]
# # Top 10 for the above

# %% [markdown]
# # Visualise the views over time for all videos and then by different podcasts

# %% [markdown]
# # Get dates Ferry was Broomhill manager and see if the volume of videos, duration, likes, comments etc. changed
